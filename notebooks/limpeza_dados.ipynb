# %% [markdown]
# ### Iniciando o projeto

# %%
import pandas as pd
aliens_db = pd.read_csv('../data/aliens.csv')
display(aliens_db)
# Out:
#               nome      serie       especie  forca  velocidade  inteligencia  \
# 0            Chama   Classico      Pyronita    7.0         6.0           5.0
# 1            Besta   Classico   Vulpimancer    8.0         7.0           3.0
# 2             XLR8   Classico  Kinecelerano    5.0        10.0           6.0
# 3   Massa Cinzenta   Classico        Galvan    1.0         4.0          10.0
# 4    Quatro Braços   Classico    Tetramando    9.0         5.0           5.0
# ..             ...        ...           ...    ...         ...           ...
# 63         Couraça   Classico  Desconhecida    NaN         NaN           NaN
# 64           Areia   Classico  Desconhecida    NaN         NaN           NaN
# 65           Chama   Classico      Pyronita    7.0         6.0           5.0
# 66   Quatro Braços   Classico    Tetramando    9.0         5.0           5.0
# 67         Vompiro  omniverse        Vladat    8.0         7.0           6.0
#
#     energia  resistencia
# ...

# %% [markdown]
# ### Excluindo dados irrelevantes

# %%
aliens_db = aliens_db.drop_duplicates(subset=['nome'])
aliens_db = aliens_db.dropna()

display(aliens_db)
# Out:
#               nome      serie       especie  forca  velocidade  inteligencia  \
# 0            Chama   Classico      Pyronita    7.0         6.0           5.0
# 1            Besta   Classico   Vulpimancer    8.0         7.0           3.0
# 2             XLR8   Classico  Kinecelerano    5.0        10.0           6.0
# 3   Massa Cinzenta   Classico        Galvan    1.0         4.0          10.0
# 4    Quatro Braços   Classico    Tetramando    9.0         5.0           5.0
# ..             ...        ...           ...    ...         ...           ...
# 57      Espantóide  Omniverse  Desconhecida    6.0         3.0           4.0
# 58        Bullfrag  Omniverse    Incurseano    7.0         7.0           5.0
# 59         Atômico  Omniverse  Desconhecida   10.0         8.0           7.0
# 60          Podrão  Omniverse        Gutrot    6.0         4.0           9.0
# 61         Vompiro  Omniverse        Vladat    8.0         7.0           6.0
#
#     energia  resistencia
# ...
